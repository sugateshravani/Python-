# %% [markdown]
# <a href="https://colab.research.google.com/github/sugateshravani/Python-/blob/main/Assignment06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [10, 20, 30, 40]

print("List:", a)

print(20 in a)
print(50 not in a)
# Out:
# List: [10, 20, 30, 40]
# True
# True

# %%
a = [10, 20, 30, 40, 50]

print(a[0])      # first element
print(a[-1])     # last element
print(a[1:4])    # slicing
# Out:
# 10
# 50
# [20, 30, 40]

# %%
a = [1, 2, 3, 4]

a[1] = 20
print(a)

a.append(5)
print(a)

a.insert(1, 100)
print(a)

a.remove(20)
print(a)
# Out:
# [1, 20, 3, 4]
# [1, 20, 3, 4, 5]
# [1, 100, 20, 3, 4, 5]
# [1, 100, 3, 4, 5]
