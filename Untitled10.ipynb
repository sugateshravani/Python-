# %% [markdown]
# <a href="https://colab.research.google.com/github/sugateshravani/Python-/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 2

while i <= 10:
    print(i)
    i += 2
# Out:
# 2
# 4
# 6
# 8
# 10
